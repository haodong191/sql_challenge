# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import psycopg2
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:PASSWORD@localhost:5432/sql_homework?')
connection = engine.connect()

# %%
salaries_data = pd.read_sql("SELECT * FROM salaries", connection)
salaries_data
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
fig=plt.figure(figsize=[20,10])
plt.hist(salaries_data['salary'])
plt.grid(axis='y')
plt.xlabel('Salary',fontsize=15)
plt.ylabel('Employee',fontsize=15)
plt.xticks()
plt.yticks()
plt.title('Salary By Employee Count',fontsize=20)
plt.show()
fig.savefig('salary_and_employee.png')

# %%
employee_data =pd.read_sql("select * from employees", connection)
employee_data.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
title_data =pd.read_sql("select * from titles", connection)
title_data
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
# title_employee = pd.merge(title_data, employee_data, lefton='title_id', how='left' )
title_employee = title_data.merge(employee_data, left_on='title_id', right_on='emp_title_id')
title_employee.head()
# Out:
#   title_id  title  emp_no emp_title_id  birth_date  first_name   last_name  \
# 0    s0001  Staff  473302        s0001  1953-07-25    Hideyuki    Zallocco
# 1    s0001  Staff  421786        s0001  1957-09-28       Xiong    Verhoeff
# 2    s0001  Staff  273487        s0001  1957-04-14   Christoph     Parfitt
# 3    s0001  Staff  246449        s0001  1958-03-23       Subbu  Bultermann
# 4    s0001  Staff   48085        s0001  1964-01-19  Venkatesan        Gilg
#
#   sex   hire_date
# 0   M  1990-04-28
# 1   M  1987-11-26
# 2   M  1991-06-28
# 3   F  1988-03-25
# 4   M  1993-06-28

# %%
title_salary = pd.merge(salaries_data, title_employee, on = 'emp_no', how = 'left')
title_salary.head()
# Out:
#    emp_no  salary title_id            title emp_title_id  birth_date  \
# 0   10001   60117    e0003  Senior Engineer        e0003  1953-09-02
# 1   10002   65828    s0001            Staff        s0001  1964-06-02
# 2   10003   40006    e0003  Senior Engineer        e0003  1959-12-03
# 3   10004   40054    e0003  Senior Engineer        e0003  1954-05-01
# 4   10005   78228    s0001            Staff        s0001  1955-01-21
#
#   first_name last_name sex   hire_date
# 0     Georgi   Facello   M  1986-06-26
# 1    Bezalel    Simmel   F  1985-11-21
# 2      Parto   Bamford   M  1986-08-28
# 3  Chirstian   Koblick   M  1986-12-01
# 4    Kyoichi  Maliniak   M  1989-09-12

# %%
avg_salaries = title_salary.groupby('title')['salary'].mean().reset_index()
avg_salaries
# Out:
#                 title        salary
# 0  Assistant Engineer  48564.434447
# 1            Engineer  48535.336511
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.799871
# 4        Senior Staff  58550.172704
# 5               Staff  58465.382850
# 6    Technique Leader  48582.896092

# %%
fig2=plt.figure(figsize=[20,10])
plt.bar(range(len(avg_salaries)), avg_salaries['salary'])
plt.xlabel('Titles',fontsize=15)
plt.xticks(range(len(avg_salaries)), avg_salaries['title'],fontsize=15)
plt.ylabel('Average Salary', fontsize = 15)
plt.yticks(fontsize=15)
plt.title('Average Salary by Title',fontsize=20)
plt.show()
fig2.savefig('average_salary_by_title.png')
